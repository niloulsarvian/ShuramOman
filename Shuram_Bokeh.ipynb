# %% [markdown]
# # Bokeh Exercises
#
# *The "User Guide" linked on this page is a very good resource :* https://bokeh.pydata.org/en/latest/

# %% [markdown]
# ## 1. Create a single Bokeh plot of some data
#
# *Include the standard pan, wheel_zoom, box_zoom, reset, save, box_select, and lasso_select tools, but no other special widgets*

# %%
#import needed libraries
import numpy as np
import pandas as pd
from bokeh.plotting import *
from bokeh.models import ColumnDataSource
output_notebook()
#output_file("index.html", title='Shuram data 1')
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
#read in data
data = pd.read_csv('Shuram Oman Project - Isotope Data.csv')
options = ['Shuram', 'Buah', "Shuram/Buah", "Khufai"]
shuramdata= data[data['formation'].isin(options)]

# %%
shuramdata.rename(columns = {'Sample Name':'name', 'Sample identifier':'ID'}, inplace = True)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4223: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(**kwargs)

# %%
shuramdata
# Out:
#               ID    name    formation minerology  composite height  d13C   \
# 0     MDE2 154.7     SO1       Shuram    Calcite             490.7 -11.30
# 1        MDE 293     SO2       Khufai   Dolomite             340.3  -6.16
# 2      MDE 287.5     SO3       Khufai   Dolomite             337.1   1.04
# 3      MDE 293.4     SO4       Khufai   Dolomite             343.0  -8.56
# 4      MDE 291.1     SO5       Khufai   Dolomite             340.7  -1.92
# 5       MDE2 1.7   SO6_A       Khufai   Dolomite             337.7  -0.29
# 6       MDE2 1.7   SO6_B       Khufai   Dolomite             337.7  -0.29
# 7       MDE2 6.6     SO7       Shuram    Calcite             422.5 -11.47
# 8     MDE2 173.6     SO8       Shuram    Calcite             509.6  -9.36
# 9      MD6 258.6     SO9       Khufai   Dolomite             340.7  -3.06
# 10       MDS 0.8    SO10  Shuram/Buah    Calcite             578.3  -9.99
# 11      MDS 21.3    SO11  Shuram/Buah    Calcite             599.6  -9.38
# 12      MDS 41.5    SO12  Shuram/Buah    Calcite             619.8  -9.32
# 13     MDS 109.6    SO13  Shuram/Buah    Calcite             687.9  -9.06
# 14     MDS 181.5    SO14  Shuram/Buah    Calcite             759.9  -7.94
# 15     MDS 200.8    SO15  Shuram/Buah    Calcite             778.3  -7.76
# 16     MDS 211.5    SO16  Shuram/Buah    Calcite             789.8  -7.40
# 17       MDS 223    SO17  Shuram/Buah    Calcite             801.3  -6.80
# 18       MDS 228    SO18  Shuram/Buah    Calcite             806.3  -4.90
# 19      MD2 45.2    SO19         Buah    Calcite             845.5  -5.88
# 20        WS 7.7    SO20       Shuram    Calcite             518.2  -9.89
# 21        WS 6.1    SO21       Shuram    Calcite             516.6  -9.80
# 22  Upper Khufai  SO22_A       Khufai   Dolomite             339.7   1.65
# 23  Upper Khufai  SO22_B       Khufai   Dolomite             339.7   1.65
# 25      WM1 59.0    SO23       Shuram    Calcite               NaN -22.44
# 26      WM1 35.8    SO24       Khufai    Calcite               NaN  -1.42
# 27      WM1 19.4   SO25A       Khufai    Calcite               NaN   5.38
# 28      WM1 19.4   SO25B       Khufai    Calcite               NaN   5.38
# 29       WM1 3.0    SO26       Khufai    Calcite               NaN  -4.16
# 30     MDE 175.3    SO27       Khufai        tbd             222.6    NaN
# 31     MDE 144.6    SO28       Khufai        tbd             191.9    NaN
# 32     MDE 101.6    SO29       Khufai   Dolomite             148.9   3.08
# 33      MDE 83.8    SO30       Khufai   Dolomite             131.1   4.52
# 34        MDE 14   SO31A       Khufai    Calcite              61.3   3.90
# 35        MDE 14   SO31B       Khufai    Calcite              61.3   3.90
#
#     d18O Through Rad Sr Columns  Through Stable Sr Columns rsWheel Number  \
# 0  -8.58                    NaN                        NaN           W968
# 1  -6.70                12/7/20                        NaN           W941
# 2  -5.62                    NaN                        NaN            NaN
# 3  -6.56                    NaN                        NaN           W968
# 4  -5.85                    NaN                        NaN           W968
# 5  -5.52                    NaN                        NaN           W978
# 6  -5.52                    NaN                        NaN           W968
# 7  -8.34                12/7/20                        NaN           W968
# 8  -8.35                    NaN                        NaN           W968
# 9  -6.34                    NaN                        NaN           W970
# 10 -8.85                    NaN                        NaN           W979
# 11 -9.27                    NaN                        NaN           W978
# 12 -9.35                12/7/20                        NaN           W941
# 13 -7.20                    NaN                        NaN          W1031
# 14 -7.48                    NaN                        NaN           W978
# 15 -7.78                12/7/20                        NaN           W941
# 16 -7.30                    NaN                        NaN           W970
# 17 -6.90                    NaN                        NaN            NaN
# 18 -7.30                12/7/20                        NaN           W941
# 19 -8.51                12/7/20                        NaN           W941
# 20 -8.48                    NaN                        NaN           W970
# 21 -8.30                    NaN                        NaN           W979
# 22 -2.63                    NaN                        NaN           W978
# 23 -2.63                    NaN                        NaN           W979
# 25 -6.91                    NaN                        NaN          W1031
# 26 -9.76                    NaN                        NaN          W1031
# 27 -9.52                    NaN                        NaN          W1031
# 28 -9.52                    NaN                        NaN          W1031
# 29 -7.55                    NaN                        NaN            NaN
# 30   NaN                    NaN                        NaN          W1031
# 31   NaN                    NaN                        NaN          W1031
# 32 -3.58                    NaN                        NaN          W1031
# 33 -2.86                    NaN                        NaN          W1031
# 34 -6.39                    NaN                        NaN          W1031
# 35 -6.39                    NaN                        NaN          W1031
#
#     ...   Mn ppm  SrCa (ppm/ppm)  Mn/Sr (ppm/ppm)  d44 higgins  \
# 0   ...   28.544           0.085           0.1164          NaN
# 1   ...    1.773           0.032           0.0229          NaN
# 2   ...    3.411           0.056           0.0287          NaN
# 3   ...    4.286           0.101           0.0272          NaN
# 4   ...    3.520           0.114           0.0195          NaN
# 5   ...    5.846           0.106           0.0278          NaN
# 6   ...    5.353           0.232           0.0125          NaN
# 7   ...   17.832           0.121           0.0587          NaN
# 8   ...    9.950           0.085           0.0349          NaN
# 9   ...    8.595           0.110           0.0502          NaN
# 10  ...   11.651           0.053           0.0628        -0.94
# 11  ...   11.265           0.068           0.0503          NaN
# 12  ...    7.391           0.097           0.0277          NaN
# 13  ...   60.444           0.003           1.0193        -0.96
# 14  ...    6.083           0.202           0.0104          NaN
# 15  ...    6.435           0.187           0.0149        -1.12
# 16  ...  121.570           0.002           1.9069          NaN
# 17  ...   17.379           0.458           0.0149          NaN
# 18  ...    4.196           2.197           0.0006          NaN
# 19  ...    6.306           0.211           0.0087        -1.31
# 20  ...    8.423           0.065           0.0408        -0.97
# 21  ...    8.797           0.064           0.0465          NaN
# 22  ...    8.914           0.077           0.0790          NaN
# 23  ...   10.334           0.050           0.1247          NaN
# 25  ...    0.000           0.173           0.0000          NaN
# 26  ...  164.397           0.523           0.2725          NaN
# 27  ...    0.466           0.413           0.0005          NaN
# 28  ...    0.236           0.246           0.0003          NaN
# 29  ...    0.257           4.921           0.0069          NaN
# 30  ...    0.000           0.051           0.0000          NaN
# 31  ...    0.245           0.030           0.0056          NaN
# 32  ...    0.294           0.094           0.0016          NaN
# 33  ...    0.395           0.076           0.0048          NaN
# 34  ...    0.504           0.031           0.0075          NaN
# 35  ...    4.317           0.016           0.1431          NaN
#
#    Primary minerology       Sr/Ca (mmol/mol)  Mg/Ca (mmol/mol)  \
# 0     Primary Calcite                    NaN               NaN
# 1            Dolomite                    NaN               NaN
# 2            Dolomite  meh, potential re run               NaN
# 3            Dolomite                    NaN               NaN
# 4            Dolomite                    NaN               NaN
# 5            Dolomite                    NaN               NaN
# 6            Dolomite                    NaN               NaN
# 7     Primary Calcite                    NaN               NaN
# 8     Primary Calcite                    NaN               NaN
# 9            Dolomite                    NaN               NaN
# 10    Primary Calcite                    NaN               NaN
# 11    Primary Calcite                    NaN               NaN
# 12    Primary Calcite                    NaN               NaN
# 13    Primary Calcite                    NaN               NaN
# 14  Primary Aragonite                    NaN               NaN
# 15  Primary Aragonite                    NaN               NaN
# 16  Primary Aragonite                    NaN               NaN
# 17  Primary Aragonite                    NaN               NaN
# 18  Primary Aragonite                    NaN               NaN
# 19  Primary Aragonite                    NaN               NaN
# 20    Primary Calcite                    NaN               NaN
# 21    Primary Calcite                    NaN               NaN
# 22           Dolomite                    NaN               NaN
# 23           Dolomite                    NaN               NaN
# 25  Primary Aragonite                    NaN               NaN
# 26  Primary Aragonite                    NaN               NaN
# 27  Primary Aragonite                    NaN               NaN
# 28  Primary Aragonite                    NaN               NaN
# 29                NaN                    NaN               NaN
# 30                tbd                    NaN               NaN
# 31                tbd                    NaN               NaN
# 32           Dolomite                    NaN               NaN
# 33           Dolomite                    NaN               NaN
# 34    Primary Calcite                    NaN               NaN
# 35    Primary Calcite                    NaN               NaN
#
#     Mn/Ca (μmol/mol)  Mn/Sr (mmol/mmol)  Mountain composite height
# 0                NaN                NaN                        NaN
# 1                NaN                NaN                        NaN
# 2                NaN                NaN                        NaN
# 3                NaN                NaN                        NaN
# 4                NaN                NaN                        NaN
# 5                NaN                NaN                        NaN
# 6                NaN                NaN                        NaN
# 7                NaN                NaN                        NaN
# 8                NaN                NaN                        NaN
# 9                NaN                NaN                        NaN
# 10               NaN                NaN                        NaN
# 11               NaN                NaN                        NaN
# 12               NaN                NaN                        NaN
# 13               NaN                NaN                        NaN
# 14               NaN                NaN                        NaN
# 15               NaN                NaN                        NaN
# 16               NaN                NaN                        NaN
# 17               NaN                NaN                        NaN
# 18               NaN                NaN                        NaN
# 19               NaN                NaN                        NaN
# 20               NaN                NaN                        NaN
# 21               NaN                NaN                        NaN
# 22               NaN                NaN                        NaN
# 23               NaN                NaN                        NaN
# 25               NaN                NaN                      134.6
# 26               NaN                NaN                       90.7
# 27               NaN                NaN                       64.2
# 28               NaN                NaN                       64.2
# 29               NaN                NaN                        5.0
# 30               NaN                NaN                        NaN
# 31               NaN                NaN                        NaN
# 32               NaN                NaN                        NaN
# 33               NaN                NaN                        NaN
# 34               NaN                NaN                        NaN
# 35               NaN                NaN                        NaN
#
# [35 rows x 63 columns]

# %%
#define source 
source = ColumnDataSource(data=dict(x0=shuramdata['87/86Sr'], 
                                    x1=shuramdata['88/86Sr'], 
                                    x2 = shuramdata['44/40Ca'],
                                    y=shuramdata['composite height'],
                                    name = shuramdata['name'],
                                    ID = shuramdata['ID']))

#call tools for bokeh plot 
TOOLS = "hover,pan,wheel_zoom,box_zoom,reset,save,box_select,lasso_select"

# %%
TOOLTIPS = [
    ('Sample Name', '@name'),
    ('Sample ID', '@ID'),
    ("isotope value", "$x"),
    ("Height (m)", "$y")
]

#create a bokeh plot
# create a new plot and add a renderer
rad = figure(tools=TOOLS, width=350, height=350, title=None, tooltips = TOOLTIPS)
rad.circle('x0', 'y', source=source, color='blue')
rad.xaxis.axis_label = '87Sr/86Sr'
rad.yaxis.axis_label = 'Height (m)'

# create another new plot and add a renderer
stab = figure(tools=TOOLS, width=350, height=350, title=None, tooltips = TOOLTIPS)
stab.circle('x1', 'y', source=source, color='red')
stab.xaxis.axis_label = 'δ88/86Sr'
stab.yaxis.axis_label = 'Height (m)'

# create a third  plot and add a renderer
d44 = figure(tools=TOOLS, width=350, height=350, title=None, tooltips = TOOLTIPS)
d44.circle('x2', 'y', source=source, color='purple')
d44.xaxis.axis_label = 'δ44/40Ca'
d44.yaxis.axis_label = 'Height (m)'



# put the subplots in a gridplot

p = gridplot([[rad, stab,d44]])

# show the results
show(p)
#
# Out:
#   <div class="bk-root" id="19653be5-ea18-4808-b30f-8feef3f678a3" data-root-id="10639"></div>

# %% [markdown]
# ## Multi-Proxy Cross plot

# %%
#define source2
source2 = ColumnDataSource(data=dict( x=shuramdata['44/40Ca'], 
                                    y=shuramdata['88/86Sr'],
                                    name = shuramdata['name'],
                                    ID = shuramdata['ID']))

# %%
# make cross plot
from bokeh.transform import linear_cmap
from bokeh.models import ColorBar, ColumnDataSource
from bokeh.palettes import Spectral6

TOOLTIPS = [
    ('Sample Name', '@name'),
    ('Sample ID', '@ID'),
    ("isotope value", "$x"),
    ("Height (m)", "$y")
]



height_so = shuramdata['composite height']
xplot = figure(tools=TOOLS, width=350, height=350, title=None, tooltips = TOOLTIPS)

#mapper = linear_cmap(field_name='height_cc', palette=Spectral6 ,low=min(height_cc), high=max(height_cc))
#xplot.circle('x', 'y', line_color=mapper, fill_alpha=1, size=12, color=mapper, source=source2)
#color_bar = ColorBar(color_mapper=mapper['transform'], width=8)
#xplot.add_layout(color_bar, 'right')

xplot.circle('x', 'y', source=source2)
xplot.xaxis.axis_label = 'δ44/40Ca'
xplot.yaxis.axis_label = 'δ88Sr/86Sr'


show(xplot)
# Out:
#   <div class="bk-root" id="567cf2aa-d59f-4ba3-87df-d0761b6ceaf8" data-root-id="13651"></div>

# %% [markdown]
# ## Multi-Proxy Cross plot - Filtered data

# %%
shuramdata2 = shuramdata[shuramdata['88/86Sr'].between(0,1)]

# %%
#define source3
source3 = ColumnDataSource(data=dict( x=shuramdata2['44/40Ca'], 
                                    y=shuramdata2['88/86Sr'],
                                    name = shuramdata2['name'],
                                    ID = shuramdata2['ID'],
                                    rad = shuramdata2['87/86Sr']))

# %%
rad
# Out:
# 0     0.709110
# 1     0.708850
# 3     0.709210
# 4     0.708600
# 5     0.708610
# 6     0.708630
# 7     0.709920
# 8     0.709660
# 9     0.708750
# 10    0.708920
# 11    0.709030
# 12    0.709030
# 14    0.709060
# 15    0.709300
# 16    0.708810
# 18    0.708690
# 19    0.708720
# 20    0.708950
# 21    0.709130
# 22    0.709120
# 23    0.708560
# 25    0.711376
# 28    0.708414
# 30    0.708512
# 31    0.708336
# 32    0.708564
# 33    0.708403
# 34    0.708688
# 35    0.708859
# Name: 87/86Sr, dtype: float64

# %%
# make cross plot
from bokeh.models import ColorBar, ColumnDataSource
from bokeh.palettes import Spectral6
from bokeh.plotting import figure, output_file, show
from bokeh.transform import linear_cmap

TOOLTIPS = [
    ('Sample Name', '@name'),
    ('Sample ID', '@ID'),
    ("δ44/40Ca (‰)", "$x"),
    ("δ88Sr/86Sr(‰)", "$y")
]


#mapper = linear_cmap(field_name='rad', palette=Spectral6 ,low=min(rad) ,high=max(rad))


pplot = figure(tools=TOOLS, width=350, height=350, title=None, tooltips = TOOLTIPS)

pplot.circle('x', 'y', line_color=mapper, color=mapper, fill_alpha=1, size=8, source=source3)
pplot.xaxis.axis_label = 'δ44/40Ca'
pplot.yaxis.axis_label = 'δ88Sr/86Sr'


show(pplot)

output_notebook()
output_file("index.html", title='Shuram data CrossPlot')
# Out:
#   <div class="bk-root" id="53b8e1ce-ce2f-4810-a334-f811cc646342" data-root-id="21017"></div>

# %%
from bokeh.models import ColorBar, ColumnDataSource
from bokeh.palettes import Spectral6
from bokeh.plotting import figure, output_file, show
from bokeh.transform import linear_cmap

output_file("styling_linear_mappers.html", title="styling_linear_mappers.py example")

x = [1,2,3,4.3333,5.3,7.4,8,9,10]
y = [1,2.3,3.4,4.5,5.6,7,8,9,10]

#Use the field name of the column source
mapper = linear_cmap(field_name='x', palette=Spectral6 ,low=min(x) ,high=max(x))

source = ColumnDataSource(dict(x=x,y=y))

p = figure(width=300, height=300, title="Linear Color Map Based on Y")

p.circle(x='x', y='y', line_color=mapper,color=mapper, fill_alpha=1, size=12, source=source)

color_bar = ColorBar(color_mapper=mapper['transform'], width=8)

p.add_layout(color_bar, 'right')

show(p)
# Out:
#   <div class="bk-root" id="400c8c38-2fdc-4896-80e4-48f4967352dc" data-root-id="20206"></div>

# %%
x
# Out:
# [1, 2, 3, 4.3333, 5.3, 7.4, 8, 9, 10]

# %% [markdown]
# ## 2. Create a single Bokeh plot of some data with some widget
#
# *Include the standard pan, wheel_zoom, box_zoom, reset, save, box_select, and lasso_select tools, and also a widget (e.g., slider, dropdown selection, etc.)  that controls some aspect of the plot*

# %%
#create a bokeh plot with a widget (interactive legend)
